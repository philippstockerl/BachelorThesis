# %% [markdown]
# <h1 style="color:#2E86C1; font-family: 'Helvetica';">d*liteOptimized.py</h2>
#
# <p style="font-size: 16px; line-height: 1.5; color:#333;">
# Implementation of the <b>D* Lite</b> dynamic path replaning algorithm.
# </p>

# %%
import os
import math
import sys
import heapq
from collections import defaultdict
from dataclasses import dataclass, field
from typing import Dict, List, Tuple
import json

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h3 style="color:#2E86C1; font-family: 'Helvetica';">(1) Data Preprocessing</h2>

# %%
@dataclass
class DStarLiteState:
    S: set
    succ: dict
    pred: dict
    cost_forecast: dict
    cost_nominal: dict
    node_positions: dict
    g: dict = field(default_factory=lambda: defaultdict(lambda: float('inf')))
    rhs: dict = field(default_factory=lambda: defaultdict(lambda: float('inf')))
    U: list = field(default_factory=list)
    k_m: float = 0.0
    s_start: int = None
    s_goal: int = None
    R_SENSE: int = field(default=1)
    robust_initialized: bool = False

# %%
def load_graph_data(nodes_csv: str, edges_csv: str):
    nodes = pd.read_csv(nodes_csv)
    edges = pd.read_csv(edges_csv)
    id_col = "id" if "id" in nodes.columns else "node_id"

    S = set(nodes[id_col].astype(int).tolist())
    node_positions = {int(row[id_col]): (row["x"], row["y"]) for _, row in nodes.iterrows()}
    cost_forecast = {(int(row.u), int(row.v)): float(row.cost) for _, row in edges.iterrows()}
    cost_nominal = {(int(row.u), int(row.v)): float(row.nominal) for _, row in edges.iterrows()}

    succ = defaultdict(list)
    pred = defaultdict(list)
    for _, row in edges.iterrows():
        u, v = int(row.u), int(row.v)
        succ[u].append(v)
        pred[v].append(u)

    return S, succ, pred, cost_forecast, cost_nominal, node_positions

# %% [markdown]
# <h3 style="color:#2E86C1; font-family: 'Helvetica';">(2) Helper Functions</h2>

# %%
def c(u, v, cost_dict):
    return cost_dict.get((u, v), float('inf'))

# %%
def h(a, b, node_positions):
    ax, ay = node_positions[a]
    bx, by = node_positions[b]
    return abs(ax - bx) + abs(ay - by)

# %%
def KeyLessThan(k1, k2):
    eps = 1e-12
    if k1[0] < k2[0] - eps: return True
    if k1[0] > k2[0] + eps: return False
    return k1[1] < k2[1] - eps

# %%
def load_robust_path(path_file: str) -> List[int]:
    if not os.path.exists(path_file):
        raise FileNotFoundError(f"Robust path file not found: {path_file}")
    df = pd.read_csv(path_file)
    col = df.columns[0]
    path_nodes = df[col].astype(int).tolist()
    print(f"Loaded robust path with {len(path_nodes)} nodes from {path_file}")
    return path_nodes

# %% [markdown]
# <h3 style="color:#2E86C1; font-family: 'Helvetica';">(3) Priority Queue Operations</h2>

# %%
def U_Remove(U, s):
    U[:] = [(key, node) for key, node in U if node != s]
    heapq.heapify(U)

# %%
def U_Insert(U, u, k):
    heapq.heappush(U, (k, u))

# %%
def U_Update(U, s, k):
    U_Remove(U, s)
    heapq.heappush(U, (k, s))

# %%
def U_TopKey(U):
    return U[0][0] if U else (float('inf'), float('inf'))

# %%
def U_Top(U):
    return U[0][1] if U else None

# %% [markdown]
# <h3 style="color:#2E86C1; font-family: 'Helvetica';">(3) Data Postprocessing</h2>

# %%
def build_dstar_breakdown(g, rhs, U, path_nodes, succ, cost_forecast, cost_nominal):
    rows, total_forecast, total_nominal = [], 0.0, 0.0
    for idx in range(len(path_nodes) - 1):
        u, v = path_nodes[idx], path_nodes[idx + 1]
        forecast_cost = cost_forecast.get((u, v), float('inf'))
        actual_cost = cost_nominal.get((u, v), float('inf'))
        deviation = actual_cost - forecast_cost
        total_forecast += forecast_cost
        total_nominal += actual_cost
        rows.append({
            "order": idx + 1,
            "u": u, "v": v,
            "forecast_cost": forecast_cost,
            "actual_cost": actual_cost,
            "deviation": deviation,
            "g_value": g[u],
            "rhs_value": rhs[u],
            "in_queue": any(node == u for _, node in U)
        })
    rows.append({
        "order": "TOTAL_FORECAST_COST",
        "forecast_cost": total_forecast,
        "actual_cost": "",
        "deviation": "",
        "g_value": "",
        "rhs_value": "",
        "in_queue": ""
    })
    return pd.DataFrame(rows), total_forecast, total_nominal

# %%
def save_dstar_results(out_dir, breakdown_df, path_nodes):
    os.makedirs(out_dir, exist_ok=True)
    breakdown_csv = os.path.join(out_dir, "dstar_solution_breakdown.csv")
    path_csv = os.path.join(out_dir, "dstar_path_nodes.csv")
    breakdown_df.to_csv(breakdown_csv, index=False)
    pd.DataFrame({"path_node_id": path_nodes}).to_csv(path_csv, index=False)
    print(f"Saved D* Lite breakdown → {breakdown_csv}")
    print(f"Saved D* Lite path nodes → {path_csv}")
    return breakdown_csv, path_csv

# %%
def plot_dstar_path_overlay(nodes_csv, edges_csv, cost_forecast, path_nodes, output_dir, total_forecast=None, total_nominal=None, robust_path=None):
    forecast_npy = edges_csv.replace("edges.csv", "actual.npy")
    cost_field = np.load(forecast_npy).T

    nodes = pd.read_csv(nodes_csv)
    id_to_idx = {int(row.id if "id" in row else row.node_id): i for i, row in nodes.iterrows()}
    coords = nodes[["x", "y"]].to_numpy()
    path_xy = np.array([coords[id_to_idx[n]] for n in path_nodes])

    plt.figure(figsize=(8, 8))
    im = plt.imshow(cost_field, origin="lower", cmap="viridis")
    plt.colorbar(im, label="Forecast Cost (normalized)")

    # --- D* Lite path ---
    plt.plot(path_xy[:, 0], path_xy[:, 1], color="red", linewidth=2, label="D* Lite Path")
    plt.scatter(path_xy[0, 0], path_xy[0, 1], color="orange", s=60, label="Start")
    plt.scatter(path_xy[-1, 0], path_xy[-1, 1], color="cyan", s=60, label="Goal")

    # --- Robust overlay (blue dashed) ---
    if robust_path is not None:
        robust_xy = np.array([coords[id_to_idx[n]] for n in robust_path])
        plt.plot(
            robust_xy[:, 0], robust_xy[:, 1],
            color="blue", linestyle="--", linewidth=2.0, label="Robust Path"
        )

    plt.legend()
    title = "D* Lite Path Overlay (forecast background, actual discovered)"
    if total_forecast is not None and total_nominal is not None:
        title += f"\nTotal Forecast Cost: {total_forecast:.2f} | Total Nominal Cost: {total_nominal:.2f}"
    plt.title(title)
    plt.tight_layout()
    out_png = os.path.join(output_dir, "dstar_path_overlay.png")
    plt.savefig(out_png)
    plt.close()
    print(f"Saved D* Lite visualization → {out_png}")
    return out_png

# %% [markdown]
# <h3 style="color:#2E86C1; font-family: 'Helvetica';">(4) Core Functions</h2>

# %%
def CalculateKey(state: DStarLiteState, s):
    val = min(state.g[s], state.rhs[s])
    return (val + h(state.s_start, s, state.node_positions) + state.k_m, val)

# %%
def UpdateVertex(state: DStarLiteState, u):
    in_queue = any(node == u for _, node in state.U)
    if state.g[u] != state.rhs[u] and in_queue:
        U_Update(state.U, u, CalculateKey(state, u))
    elif state.g[u] != state.rhs[u] and not in_queue:
        U_Insert(state.U, u, CalculateKey(state, u))
    elif state.g[u] == state.rhs[u] and in_queue:
        U_Remove(state.U, u)

# %%
def Initialize(state: DStarLiteState):
    state.U.clear()
    state.k_m = 0.0
    for s in state.S:
        state.g[s] = float('inf')
        state.rhs[s] = float('inf')

    state.rhs[state.s_goal] = 0.0
    U_Insert(state.U, state.s_goal, CalculateKey(state, state.s_goal))
    UpdateVertex(state, state.s_start)

# %%
def ComputeShortestPath(state: DStarLiteState):
    while (KeyLessThan(U_TopKey(state.U), CalculateKey(state, state.s_start))
           or state.rhs[state.s_start] != state.g[state.s_start]):

        if not state.U:
            break

        k_old, u = heapq.heappop(state.U)
        k_new = CalculateKey(state, u)

        if KeyLessThan(k_old, k_new):
            U_Insert(state.U, u, k_new)
            continue

        if state.g[u] > state.rhs[u]:
            state.g[u] = state.rhs[u]
            for s in state.pred[u]:
                if s != state.s_goal:
                    state.rhs[s] = min(state.rhs[s], c(s, u, state.cost_forecast) + state.g[u])
                UpdateVertex(state, s)
        else:
            g_old = state.g[u]
            state.g[u] = float('inf')
            for s in (list(state.pred[u]) + [u]):
                if state.rhs[s] == c(s, u, state.cost_forecast) + g_old:
                    if s != state.s_goal:
                        state.rhs[s] = min(
                            (c(s, sp, state.cost_forecast) + state.g[sp]) for sp in state.succ[s]
                        )
                UpdateVertex(state, s)

# %%
def scan_for_edge_changes(state: DStarLiteState, threshold=1e-6, current_node=None, radius=1):
    if current_node is None:
        return []

    visited = {current_node}
    frontier = [current_node]
    changed = []

    for _ in range(radius):
        new_frontier = []
        for u in frontier:
            for v in state.succ[u]:
                forecast_val = state.cost_forecast.get((u, v))
                nominal_val  = state.cost_nominal.get((u, v))
                if nominal_val is None:
                    continue
                if abs(forecast_val - nominal_val) > threshold:
                    changed.append((u, v))
                if v not in visited:
                    visited.add(v)
                    new_frontier.append(v)
        frontier = new_frontier
    return changed

# %%
def execute_dstar_from_robust_path(state: DStarLiteState, robust_path: List[int]):
    """Option B – Follow robust path until changes trigger replanning."""
    path_nodes = [state.s_start]
    for next_node in robust_path[1:]:
        state.s_start = next_node
        path_nodes.append(next_node)
        changed_edges = scan_for_edge_changes(state, current_node=state.s_start, radius=state.R_SENSE)
        if changed_edges:
            print(f"Detected {len(changed_edges)} changes near {state.s_start} → replanning.")
            state.k_m += 1
            for (u, v) in changed_edges:
                new_cost = c(u, v, state.cost_nominal)
                state.cost_forecast[(u, v)] = new_cost
                UpdateVertex(state, u)
            ComputeShortestPath(state)
    return path_nodes

# %%
def initialize_dstar_with_path(state: DStarLiteState, path_nodes: List[int]):
    """Pre-initialize g/rhs along robust path (warm-start)."""
    for i in range(len(path_nodes) - 1):
        u, v = path_nodes[i], path_nodes[i + 1]
        est_cost = c(u, v, state.cost_forecast)
        state.g[u] = est_cost
        state.rhs[u] = est_cost
    print("Initialized D* Lite state with robust path priors (warm-start).")

# %%
def initialize_from_robust_path(state: DStarLiteState, robust_path: List[int]):
    """
    Initialize D* Lite's g and rhs values by processing the robust path
    as if performing a partial backward search (goal -> start).
    """
    state.robust_initialized = True
    # Reset internal values
    state.U.clear()
    for s in state.S:
        state.g[s] = float('inf')
        state.rhs[s] = float('inf')

    # --- Set goal as usual ---
    goal = robust_path[-1]
    state.s_goal = goal
    state.rhs[goal] = 0.0
    U_Insert(state.U, goal, CalculateKey(state, goal))

    # --- Backward relaxations along the robust path ---
    expanded = 0
    for i in range(len(robust_path) - 2, -1, -1):  # from second-to-last → start
        u, v = robust_path[i], robust_path[i + 1]
        cost = c(u, v, state.cost_forecast)
        state.rhs[u] = min(state.rhs[u], cost + state.g[v])
        UpdateVertex(state, u)
        ComputeShortestPath(state)
        expanded += 1

    print(f"✅ Initialized D* Lite along robust path ({expanded} nodes processed).")

# %%
def Main(state: DStarLiteState, output_dir=None, visualize=True, nodes_csv=None,
         edges_csv=None, cost_forecast_initial=None, robust_path=None):

    if getattr(state, "robust_initialized", False):
        print("⚙️ Using robust-initialized state – skipping Initialize()")
    else:
        print("🧠 Performing standard D* Lite initialization (A* backward).")
        Initialize(state)
        ComputeShortestPath(state)

    s_last = state.s_start
    path_nodes, step = [state.s_start], 0

    # --- Main forward execution loop ---
    while state.s_start != state.s_goal:
        if state.g[state.s_start] == float('inf'):
            print("No valid path to goal!")
            break
        succ_nodes = state.succ[state.s_start]
        if not succ_nodes:
            print("No successors available from start!")
            break

        state.s_start = min(succ_nodes, key=lambda sp: c(state.s_start, sp, state.cost_forecast) + state.g[sp])
        path_nodes.append(state.s_start)
        step += 1

        changed_edges = scan_for_edge_changes(state, current_node=state.s_start, radius=state.R_SENSE)
        print(f"Step {step}: discovered {len(changed_edges)} changed edges within radius {state.R_SENSE}")

        if changed_edges:
            state.k_m += h(s_last, state.s_start, state.node_positions)
            s_last = state.s_start
            for (u, v) in changed_edges:
                c_old = c(u, v, state.cost_forecast)
                new_cost = c(u, v, state.cost_nominal)
                state.cost_forecast[(u, v)] = new_cost
                if c_old > new_cost:
                    if u != state.s_goal:
                        state.rhs[u] = min(state.rhs[u], new_cost + state.g[v])
                elif state.rhs[u] == c_old + state.g[v]:
                    if u != state.s_goal:
                        state.rhs[u] = min(c(u, sp, state.cost_forecast) + state.g[sp] for sp in state.succ[u])
                UpdateVertex(state, u)
            # --- Diagnostic section ---
            print(f"Step {step}: {len(changed_edges)} changes detected.")
            before_g = state.g[state.s_start]
            ComputeShortestPath(state)
            after_g = state.g[state.s_start]
            print(f"  → g[{state.s_start}] before={before_g:.4f}, after={after_g:.4f}")

    # --- Postprocessing and export ---
    breakdown_df, total_forecast, total_nominal = build_dstar_breakdown(
        state.g, state.rhs, state.U, path_nodes, state.succ, cost_forecast_initial, state.cost_nominal
    )
    breakdown_csv, path_csv = save_dstar_results(output_dir, breakdown_df, path_nodes)
    if visualize:
        plot_dstar_path_overlay(nodes_csv, edges_csv, state.cost_forecast, path_nodes, output_dir,
                                total_forecast, total_nominal, robust_path=robust_path)
    print(f"\nFinal D* Lite path has {len(path_nodes)} nodes.")
    print(f"Total Nominal Cost = {total_nominal:.3f}, Forecast Cost = {total_forecast:.3f}")
    return {
        "path_nodes": path_nodes,
        "breakdown_csv": breakdown_csv,
        "path_csv": path_csv,
        "total_nominal": total_nominal,
        "total_forecast": total_forecast
    }

# %%
def run_dstar():
    dir = "/Users/philippstockerl/BachelorThesis/Data/master17/seed_10864_grid100_Stable_ls30.0_var1.0_nug1.0"
    nodes_csv = f"{dir}/nodes.csv"
    edges_csv = f"{dir}/edges.csv"
    params_json = "/Users/philippstockerl/BachelorThesis/Organized/parameters.json"

    # --- Load parameters ---
    if os.path.exists(params_json):
        with open(params_json, "r") as f:
            params = json.load(f)
        print(f"Loaded parameters from {params_json}")
    else:
        raise FileNotFoundError(f"Parameters file not found: {params_json}")

    S, succ, pred, cost_forecast, cost_nominal, node_positions = load_graph_data(nodes_csv, edges_csv)
    cost_forecast_initial = dict(cost_forecast)

    general_params = params.get("general", {})
    dstar_params = params.get("dstar", {})

    print("\nLoaded parameters:")
    print("  Sensing radius:", dstar_params.get("sensing_radius", 1))
    print("  Visualization:", dstar_params.get("visualize", general_params.get("visualize", True)))
    print("  Output dir:", dstar_params.get("output_dir") or general_params.get("output_dir", "dstar_results"))

    robust_path = None
    if dstar_params.get("use_robust_path", False):
        robust_path_file = "/Users/philippstockerl/BachelorThesis/Data/master17/seed_10864_grid100_Stable_ls30.0_var1.0_nug1.0/robust_Gamma_39600.0/robust_path_nodes.csv"
        robust_path = load_robust_path(robust_path_file)

    state = DStarLiteState(
        S=S, succ=succ, pred=pred,
        cost_forecast=cost_forecast,
        cost_nominal=cost_nominal,
        node_positions=node_positions,
        R_SENSE=dstar_params.get("sensing_radius", 1)
    )
    state.s_start = min(S)
    state.s_goal = max(S)

    if robust_path:
        mode = dstar_params.get("robust_mode", "warm_start")
        guided_variant = dstar_params.get("guided_variant", "pure")
        reopt_distance = int(dstar_params.get("reopt_distance", 50))

        if mode == "warm_start":
            initialize_dstar_with_path(state, robust_path)

        elif mode == "robust_init":
            initialize_from_robust_path(state, robust_path)
            # skip normal Initialize() later (we’ll handle that in Step 3)

        elif mode == "guided":
            guided_nodes = execute_dstar_from_robust_path(state, robust_path)
            print(f"Guided D* Lite executed {len(guided_nodes)} steps with online replanning.")

            out_dir = os.path.join(dir, dstar_params.get("output_dir", "dstar_results"))
            os.makedirs(out_dir, exist_ok=True)

            guided_csv = os.path.join(out_dir, "dstar_guided_path_nodes.csv")
            pd.DataFrame({"path_node_id": guided_nodes}).to_csv(guided_csv, index=False)
            print(f"Saved guided path → {guided_csv}")

            plot_dstar_path_overlay(
                nodes_csv, edges_csv, state.cost_forecast, guided_nodes,
                output_dir=out_dir, robust_path=robust_path
            )

            if guided_variant == "pure":
                print("✅ Guided simulation complete (pure mode). No global reoptimization.")
                return  # <— safe exit point instead of killing the kernel

            elif guided_variant == "hybrid":
                if reopt_distance > len(guided_nodes):
                    reopt_distance = len(guided_nodes) - 1
                state.s_start = guided_nodes[-reopt_distance]
                print(f"🔁 Hybrid mode: continuing reoptimization from node "
                      f"{state.s_start} ({reopt_distance} steps before goal).")

    out_dir = os.path.join(dir, dstar_params.get("output_dir") or general_params.get("output_dir", "dstar_results"))
    result = Main(
        state,
        output_dir=out_dir,
        visualize=dstar_params.get("visualize", general_params.get("visualize", True)),
        nodes_csv=nodes_csv,
        edges_csv=edges_csv,
        cost_forecast_initial=cost_forecast_initial,
        robust_path=robust_path
    )

    print("\n=== D* Lite Export Summary ===")
    print(f"Path CSV: {result['path_csv']}")
    print(f"Breakdown CSV: {result['breakdown_csv']}")
    print(f"Total Nominal Cost: {result['total_nominal']:.3f}")
    print(f"Total Forecast Cost: {result['total_forecast']:.3f}")

# %%
if __name__ == "__main__":
    run_dstar()
# Out:
# Loaded parameters from /Users/philippstockerl/BachelorThesis/Organized/parameters.json
#
# Loaded parameters:
#   Sensing radius: 1
#   Visualization: True
#   Output dir: dstar_results
# Loaded robust path with 199 nodes from /Users/philippstockerl/BachelorThesis/Data/master17/seed_10864_grid100_Stable_ls30.0_var1.0_nug1.0/robust_Gamma_39600.0/robust_path_nodes.csv
# ✅ Initialized D* Lite along robust path (198 nodes processed).
# ⚙️ Using robust-initialized state – skipping Initialize()
# Step 1: discovered 3 changed edges within radius 1
# Step 1: 3 changes detected.
#   → g[100] before=89.6393, after=89.9865
# Step 2: discovered 3 changed edges within radius 1
# Step 2: 3 changes detected.
#   → g[200] before=89.0388, after=89.4832
# Step 3: discovered 3 changed edges within radius 1
# Step 3: 3 changes detected.
#   → g[300] before=88.5497, after=88.7858
# Step 4: discovered 3 changed edges within radius 1
# Step 4: 3 changes detected.
#   → g[400] before=87.8596, after=88.0064
# Step 5: discovered 3 changed edges within radius 1
# Step 5: 3 changes detected.
#   → g[500] before=87.0846, after=87.2887
# Step 6: discovered 3 changed edges within radius 1
# Step 6: 3 changes detected.
#   → g[600] before=86.3769, after=86.5439
# Step 7: discovered 3 changed edges within radius 1
# Step 7: 3 changes detected.
#   → g[700] before=85.6534, after=85.8645
# Step 8: discovered 3 changed edges within radius 1
# Step 8: 3 changes detected.
#   → g[800] before=85.0053, after=85.2702
# Step 9: discovered 4 changed edges within radius 1
# Step 9: 4 changes detected.
#   → g[801] before=84.4446, after=84.6829
# Step 10: discovered 4 changed edges within radius 1
# Step 10: 4 changes detected.
#   → g[802] before=83.9044, after=84.1090
# Step 11: discovered 4 changed edges within radius 1
# Step 11: 4 changes detected.
#   → g[803] before=83.3635, after=83.5325
# Step 12: discovered 4 changed edges within radius 1
# Step 12: 4 changes detected.
#   → g[804] before=82.8041, after=82.9996
# Step 13: discovered 4 changed edges within radius 1
# Step 13: 4 changes detected.
#   → g[805] before=82.2748, after=82.6084
# Step 14: discovered 4 changed edges within radius 1
# Step 14: 4 changes detected.
#   → g[905] before=81.8776, after=82.1554
# Step 15: discovered 4 changed edges within radius 1
# Step 15: 4 changes detected.
#   → g[1005] before=81.4311, after=81.6356
# Step 16: discovered 4 changed edges within radius 1
# Step 16: 4 changes detected.
#   → g[1105] before=80.9140, after=81.1875
# Step 17: discovered 4 changed edges within radius 1
# Step 17: 4 changes detected.
#   → g[1205] before=80.4620, after=80.6199
# Step 18: discovered 4 changed edges within radius 1
# Step 18: 4 changes detected.
#   → g[1305] before=79.8811, after=80.1822
# Step 19: discovered 4 changed edges within radius 1
# Step 19: 4 changes detected.
#   → g[1405] before=79.4211, after=79.6032
# Step 20: discovered 4 changed edges within radius 1
# Step 20: 4 changes detected.
#   → g[1505] before=78.8163, after=79.1041
# Step 21: discovered 4 changed edges within radius 1
# Step 21: 4 changes detected.
#   → g[1506] before=78.2964, after=78.5587
# Step 22: discovered 4 changed edges within radius 1
# Step 22: 4 changes detected.
#   → g[1606] before=77.7411, after=78.0231
# Step 23: discovered 4 changed edges within radius 1
# Step 23: 4 changes detected.
#   → g[1607] before=77.2101, after=77.4644
# Step 24: discovered 4 changed edges within radius 1
# Step 24: 4 changes detected.
#   → g[1608] before=76.6602, after=76.9783
# Step 25: discovered 4 changed edges within radius 1
# Step 25: 4 changes detected.
#   → g[1609] before=76.1900, after=76.5197
# Step 26: discovered 4 changed edges within radius 1
# Step 26: 4 changes detected.
#   → g[1709] before=75.7493, after=76.0495
# Step 27: discovered 4 changed edges within radius 1
# Step 27: 4 changes detected.
#   → g[1710] before=75.2981, after=75.5764
# Step 28: discovered 4 changed edges within radius 1
# Step 28: 4 changes detected.
#   → g[1711] before=74.8307, after=75.0416
# Step 29: discovered 4 changed edges within radius 1
# Step 29: 4 changes detected.
#   → g[1811] before=74.2952, after=74.4878
# Step 30: discovered 4 changed edges within radius 1
# Step 30: 4 changes detected.
#   → g[1812] before=73.7586, after=73.9960
# Step 31: discovered 4 changed edges within radius 1
# Step 31: 4 changes detected.
#   → g[1813] before=73.2665, after=73.6322
# Step 32: discovered 4 changed edges within radius 1
# Step 32: 4 changes detected.
#   → g[1913] before=72.9051, after=73.2686
# Step 33: discovered 4 changed edges within radius 1
# Step 33: 4 changes detected.
#   → g[2013] before=72.5681, after=72.6735
# Step 34: discovered 4 changed edges within radius 1
# Step 34: 4 changes detected.
#   → g[2113] before=71.9974, after=72.0697
# Step 35: discovered 4 changed edges within radius 1
# Step 35: 4 changes detected.
#   → g[2114] before=71.4141, after=71.4406
# Step 36: discovered 4 changed edges within radius 1
# Step 36: 4 changes detected.
#   → g[2115] before=70.7839, after=71.0004
# Step 37: discovered 4 changed edges within radius 1
# Step 37: 4 changes detected.
#   → g[2215] before=70.3397, after=70.3969
# Step 38: discovered 4 changed edges within radius 1
# Step 38: 4 changes detected.
#   → g[2216] before=69.7646, after=69.8666
# Step 39: discovered 4 changed edges within radius 1
# Step 39: 4 changes detected.
#   → g[2316] before=69.2347, after=69.4801
# Step 40: discovered 4 changed edges within radius 1
# Step 40: 4 changes detected.
#   → g[2317] before=68.8901, after=68.9671
# Step 41: discovered 4 changed edges within radius 1
# Step 41: 4 changes detected.
#   → g[2417] before=68.3807, after=68.4289
# Step 42: discovered 4 changed edges within radius 1
# Step 42: 4 changes detected.
#   → g[2517] before=67.8887, after=67.9843
# Step 43: discovered 4 changed edges within radius 1
# Step 43: 4 changes detected.
#   → g[2518] before=67.4817, after=67.7135
# Step 44: discovered 4 changed edges within radius 1
# Step 44: 4 changes detected.
#   → g[2519] before=67.2193, after=67.1657
# Step 45: discovered 4 changed edges within radius 1
# Step 45: 4 changes detected.
#   → g[2520] before=66.6782, after=66.6397
# Step 46: discovered 4 changed edges within radius 1
# Step 46: 4 changes detected.
#   → g[2521] before=66.1600, after=66.2253
# Step 47: discovered 4 changed edges within radius 1
# Step 47: 4 changes detected.
#   → g[2522] before=65.7498, after=65.9043
# Step 48: discovered 4 changed edges within radius 1
# Step 48: 4 changes detected.
#   → g[2622] before=65.4191, after=65.4015
# Step 49: discovered 4 changed edges within radius 1
# Step 49: 4 changes detected.
#   → g[2623] before=64.9655, after=64.8769
# Step 50: discovered 4 changed edges within radius 1
# Step 50: 4 changes detected.
#   → g[2624] before=64.4135, after=64.6259
# Step 51: discovered 4 changed edges within radius 1
# Step 51: 4 changes detected.
#   → g[2724] before=64.1111, after=64.3145
# Step 52: discovered 4 changed edges within radius 1
# Step 52: 4 changes detected.
#   → g[2725] before=63.8439, after=63.8448
# Step 53: discovered 4 changed edges within radius 1
# Step 53: 4 changes detected.
#   → g[2726] before=63.3142, after=63.4568
# Step 54: discovered 4 changed edges within radius 1
# Step 54: 4 changes detected.
#   → g[2826] before=62.8687, after=63.0877
# Step 55: discovered 4 changed edges within radius 1
# Step 55: 4 changes detected.
#   → g[2926] before=62.5330, after=62.6807
# Step 56: discovered 4 changed edges within radius 1
# Step 56: 4 changes detected.
#   → g[2927] before=62.1426, after=62.2574
# Step 57: discovered 4 changed edges within radius 1
# Step 57: 4 changes detected.
#   → g[3027] before=61.6962, after=61.8718
# Step 58: discovered 4 changed edges within radius 1
# Step 58: 4 changes detected.
#   → g[3028] before=61.3328, after=61.3392
# Step 59: discovered 4 changed edges within radius 1
# Step 59: 4 changes detected.
#   → g[3029] before=60.8090, after=60.7921
# Step 60: discovered 4 changed edges within radius 1
# Step 60: 4 changes detected.
#   → g[3129] before=60.2792, after=60.3233
# Step 61: discovered 4 changed edges within radius 1
# Step 61: 4 changes detected.
#   → g[3229] before=59.8489, after=59.9223
# Step 62: discovered 4 changed edges within radius 1
# Step 62: 4 changes detected.
#   → g[3230] before=59.4767, after=59.6974
# Step 63: discovered 4 changed edges within radius 1
# Step 63: 4 changes detected.
#   → g[3231] before=59.2711, after=59.2887
# Step 64: discovered 4 changed edges within radius 1
# Step 64: 4 changes detected.
#   → g[3232] before=58.8639, after=58.9366
# Step 65: discovered 4 changed edges within radius 1
# Step 65: 4 changes detected.
#   → g[3233] before=58.4894, after=58.5363
# Step 66: discovered 4 changed edges within radius 1
# Step 66: 4 changes detected.
#   → g[3234] before=58.0477, after=58.1851
# Step 67: discovered 4 changed edges within radius 1
# Step 67: 4 changes detected.
#   → g[3334] before=57.6513, after=57.6510
# Step 68: discovered 4 changed edges within radius 1
# Step 68: 4 changes detected.
#   → g[3335] before=57.1571, after=57.2108
# Step 69: discovered 4 changed edges within radius 1
# Step 69: 4 changes detected.
#   → g[3336] before=56.6903, after=56.7413
# Step 70: discovered 4 changed edges within radius 1
# Step 70: 4 changes detected.
#   → g[3436] before=56.2111, after=56.3268
# Step 71: discovered 4 changed edges within radius 1
# Step 71: 4 changes detected.
#   → g[3437] before=55.8234, after=56.0527
# Step 72: discovered 4 changed edges within radius 1
# Step 72: 4 changes detected.
#   → g[3537] before=55.5499, after=55.7322
# Step 73: discovered 4 changed edges within radius 1
# Step 73: 4 changes detected.
#   → g[3538] before=55.2366, after=55.3220
# Step 74: discovered 4 changed edges within radius 1
# Step 74: 4 changes detected.
#   → g[3638] before=54.8187, after=54.8244
# Step 75: discovered 4 changed edges within radius 1
# Step 75: 4 changes detected.
#   → g[3738] before=54.3102, after=54.3467
# Step 76: discovered 4 changed edges within radius 1
# Step 76: 4 changes detected.
#   → g[3838] before=53.8175, after=53.8190
# Step 77: discovered 4 changed edges within radius 1
# Step 77: 4 changes detected.
#   → g[3839] before=53.2766, after=53.5222
# Step 78: discovered 4 changed edges within radius 1
# Step 78: 4 changes detected.
#   → g[3840] before=52.9661, after=53.1523
# Step 79: discovered 4 changed edges within radius 1
# Step 79: 4 changes detected.
#   → g[3841] before=52.5941, after=52.6769
# Step 80: discovered 4 changed edges within radius 1
# Step 80: 4 changes detected.
#   → g[3941] before=52.1270, after=52.2936
# Step 81: discovered 4 changed edges within radius 1
# Step 81: 4 changes detected.
#   → g[3942] before=51.7563, after=51.7232
# Step 82: discovered 4 changed edges within radius 1
# Step 82: 4 changes detected.
#   → g[4042] before=51.1941, after=51.1747
# Step 83: discovered 4 changed edges within radius 1
# Step 83: 4 changes detected.
#   → g[4142] before=50.6655, after=50.6898
# Step 84: discovered 4 changed edges within radius 1
# Step 84: 4 changes detected.
#   → g[4143] before=50.2048, after=50.4427
# Step 85: discovered 4 changed edges within radius 1
# Step 85: 4 changes detected.
#   → g[4243] before=49.9510, after=50.0312
# Step 86: discovered 4 changed edges within radius 1
# Step 86: 4 changes detected.
#   → g[4343] before=49.5550, after=49.5065
# Step 87: discovered 4 changed edges within radius 1
# Step 87: 4 changes detected.
#   → g[4344] before=49.0386, after=49.2082
# Step 88: discovered 4 changed edges within radius 1
# Step 88: 4 changes detected.
#   → g[4345] before=48.7291, after=48.7905
# Step 89: discovered 4 changed edges within radius 1
# Step 89: 4 changes detected.
#   → g[4346] before=48.3083, after=48.4907
# Step 90: discovered 4 changed edges within radius 1
# Step 90: 4 changes detected.
#   → g[4446] before=48.0168, after=48.1260
# Step 91: discovered 4 changed edges within radius 1
# Step 91: 4 changes detected.
#   → g[4546] before=47.6407, after=47.7009
# Step 92: discovered 4 changed edges within radius 1
# Step 92: 4 changes detected.
#   → g[4547] before=47.2125, after=47.2265
# Step 93: discovered 4 changed edges within radius 1
# Step 93: 4 changes detected.
#   → g[4548] before=46.7414, after=46.7769
# Step 94: discovered 4 changed edges within radius 1
# Step 94: 4 changes detected.
#   → g[4648] before=46.2979, after=46.3701
# Step 95: discovered 4 changed edges within radius 1
# Step 95: 4 changes detected.
#   → g[4649] before=45.8780, after=45.9898
# Step 96: discovered 4 changed edges within radius 1
# Step 96: 4 changes detected.
#   → g[4650] before=45.4862, after=45.6565
# Step 97: discovered 4 changed edges within radius 1
# Step 97: 4 changes detected.
#   → g[4750] before=45.1384, after=45.3083
# Step 98: discovered 4 changed edges within radius 1
# Step 98: 4 changes detected.
#   → g[4850] before=44.7548, after=44.8788
# Step 99: discovered 4 changed edges within radius 1
# Step 99: 4 changes detected.
#   → g[4851] before=44.2994, after=44.4750
# Step 100: discovered 4 changed edges within radius 1
# Step 100: 4 changes detected.
#   → g[4951] before=43.8686, after=44.2483
# Step 101: discovered 4 changed edges within radius 1
# Step 101: 4 changes detected.
#   → g[4952] before=43.6207, after=43.7356
# Step 102: discovered 4 changed edges within radius 1
# Step 102: 4 changes detected.
#   → g[5052] before=43.0910, after=43.2578
# Step 103: discovered 4 changed edges within radius 1
# Step 103: 4 changes detected.
#   → g[5053] before=42.5964, after=42.8156
# Step 104: discovered 4 changed edges within radius 1
# Step 104: 4 changes detected.
#   → g[5153] before=42.1475, after=42.3402
# Step 105: discovered 4 changed edges within radius 1
# Step 105: 4 changes detected.
#   → g[5154] before=41.6657, after=41.9757
# Step 106: discovered 4 changed edges within radius 1
# Step 106: 4 changes detected.
#   → g[5254] before=41.3089, after=41.4069
# Step 107: discovered 4 changed edges within radius 1
# Step 107: 4 changes detected.
#   → g[5255] before=40.7573, after=40.9468
# Step 108: discovered 4 changed edges within radius 1
# Step 108: 4 changes detected.
#   → g[5256] before=40.3200, after=40.5113
# Step 109: discovered 4 changed edges within radius 1
# Step 109: 4 changes detected.
#   → g[5257] before=39.9032, after=40.0556
# Step 110: discovered 4 changed edges within radius 1
# Step 110: 4 changes detected.
#   → g[5357] before=39.4598, after=39.4687
# Step 111: discovered 4 changed edges within radius 1
# Step 111: 4 changes detected.
#   → g[5457] before=38.9194, after=39.0773
# Step 112: discovered 4 changed edges within radius 1
# Step 112: 4 changes detected.
#   → g[5557] before=38.5695, after=38.5101
# Step 113: discovered 4 changed edges within radius 1
# Step 113: 4 changes detected.
#   → g[5558] before=38.0216, after=38.1697
# Step 114: discovered 4 changed edges within radius 1
# Step 114: 4 changes detected.
#   → g[5559] before=37.6911, after=37.7108
# Step 115: discovered 4 changed edges within radius 1
# Step 115: 4 changes detected.
#   → g[5560] before=37.2350, after=37.3668
# Step 116: discovered 4 changed edges within radius 1
# Step 116: 4 changes detected.
#   → g[5660] before=36.8926, after=37.0368
# Step 117: discovered 4 changed edges within radius 1
# Step 117: 4 changes detected.
#   → g[5760] before=36.5680, after=36.5101
# Step 118: discovered 4 changed edges within radius 1
# Step 118: 4 changes detected.
#   → g[5761] before=36.0348, after=36.0657
# Step 119: discovered 4 changed edges within radius 1
# Step 119: 4 changes detected.
#   → g[5861] before=35.6023, after=35.8518
# Step 120: discovered 4 changed edges within radius 1
# Step 120: 4 changes detected.
#   → g[5961] before=35.3837, after=35.4246
# Step 121: discovered 4 changed edges within radius 1
# Step 121: 4 changes detected.
#   → g[6061] before=34.9542, after=35.0202
# Step 122: discovered 4 changed edges within radius 1
# Step 122: 4 changes detected.
#   → g[6062] before=34.5524, after=34.6755
# Step 123: discovered 4 changed edges within radius 1
# Step 123: 4 changes detected.
#   → g[6162] before=34.2207, after=34.3481
# Step 124: discovered 4 changed edges within radius 1
# Step 124: 4 changes detected.
#   → g[6262] before=33.8885, after=33.9773
# Step 125: discovered 4 changed edges within radius 1
# Step 125: 4 changes detected.
#   → g[6263] before=33.5191, after=33.5932
# Step 126: discovered 4 changed edges within radius 1
# Step 126: 4 changes detected.
#   → g[6363] before=33.1422, after=33.2564
# Step 127: discovered 4 changed edges within radius 1
# Step 127: 4 changes detected.
#   → g[6364] before=32.8081, after=32.8781
# Step 128: discovered 4 changed edges within radius 1
# Step 128: 4 changes detected.
#   → g[6464] before=32.4476, after=32.6133
# Step 129: discovered 4 changed edges within radius 1
# Step 129: 4 changes detected.
#   → g[6564] before=32.1816, after=32.2749
# Step 130: discovered 4 changed edges within radius 1
# Step 130: 4 changes detected.
#   → g[6565] before=31.8430, after=31.7850
# Step 131: discovered 4 changed edges within radius 1
# Step 131: 4 changes detected.
#   → g[6566] before=31.3527, after=31.4774
# Step 132: discovered 4 changed edges within radius 1
# Step 132: 4 changes detected.
#   → g[6666] before=31.0569, after=31.0662
# Step 133: discovered 4 changed edges within radius 1
# Step 133: 4 changes detected.
#   → g[6766] before=30.6200, after=30.5780
# Step 134: discovered 4 changed edges within radius 1
# Step 134: 4 changes detected.
#   → g[6866] before=30.1110, after=30.1143
# Step 135: discovered 4 changed edges within radius 1
# Step 135: 4 changes detected.
#   → g[6966] before=29.6329, after=29.6948
# Step 136: discovered 4 changed edges within radius 1
# Step 136: 4 changes detected.
#   → g[6967] before=29.2029, after=29.2483
# Step 137: discovered 4 changed edges within radius 1
# Step 137: 4 changes detected.
#   → g[6968] before=28.7564, after=28.8023
# Step 138: discovered 4 changed edges within radius 1
# Step 138: 4 changes detected.
#   → g[7068] before=28.3130, after=28.3565
# Step 139: discovered 4 changed edges within radius 1
# Step 139: 4 changes detected.
#   → g[7168] before=27.8340, after=27.9380
# Step 140: discovered 4 changed edges within radius 1
# Step 140: 4 changes detected.
#   → g[7268] before=27.3890, after=27.4070
# Step 141: discovered 4 changed edges within radius 1
# Step 141: 4 changes detected.
#   → g[7368] before=26.8379, after=26.9430
# Step 142: discovered 4 changed edges within radius 1
# Step 142: 4 changes detected.
#   → g[7369] before=26.3544, after=26.5100
# Step 143: discovered 4 changed edges within radius 1
# Step 143: 4 changes detected.
#   → g[7469] before=25.9134, after=26.0633
# Step 144: discovered 4 changed edges within radius 1
# Step 144: 4 changes detected.
#   → g[7569] before=25.4483, after=25.6562
# Step 145: discovered 4 changed edges within radius 1
# Step 145: 4 changes detected.
#   → g[7570] before=25.0047, after=24.9639
# Step 146: discovered 4 changed edges within radius 1
# Step 146: 4 changes detected.
#   → g[7670] before=24.3211, after=24.4000
# Step 147: discovered 4 changed edges within radius 1
# Step 147: 4 changes detected.
#   → g[7671] before=23.7123, after=23.9605
# Step 148: discovered 4 changed edges within radius 1
# Step 148: 4 changes detected.
#   → g[7672] before=23.2956, after=23.3813
# Step 149: discovered 4 changed edges within radius 1
# Step 149: 4 changes detected.
#   → g[7673] before=22.7395, after=22.8267
# Step 150: discovered 4 changed edges within radius 1
# Step 150: 4 changes detected.
#   → g[7773] before=22.2087, after=22.4449
# Step 151: discovered 4 changed edges within radius 1
# Step 151: 4 changes detected.
#   → g[7774] before=21.8102, after=22.0088
# Step 152: discovered 4 changed edges within radius 1
# Step 152: 4 changes detected.
#   → g[7775] before=21.4059, after=21.5694
# Step 153: discovered 4 changed edges within radius 1
# Step 153: 4 changes detected.
#   → g[7776] before=21.0007, after=21.2751
# Step 154: discovered 4 changed edges within radius 1
# Step 154: 4 changes detected.
#   → g[7777] before=20.7453, after=20.7099
# Step 155: discovered 4 changed edges within radius 1
# Step 155: 4 changes detected.
#   → g[7778] before=20.2211, after=20.3071
# Step 156: discovered 4 changed edges within radius 1
# Step 156: 4 changes detected.
#   → g[7878] before=19.8548, after=19.9110
# Step 157: discovered 4 changed edges within radius 1
# Step 157: 4 changes detected.
#   → g[7978] before=19.4423, after=19.5223
# Step 158: discovered 4 changed edges within radius 1
# Step 158: 4 changes detected.
#   → g[7979] before=19.0278, after=19.0949
# Step 159: discovered 4 changed edges within radius 1
# Step 159: 4 changes detected.
#   → g[8079] before=18.6290, after=18.6444
# Step 160: discovered 4 changed edges within radius 1
# Step 160: 4 changes detected.
#   → g[8179] before=18.1421, after=18.2211
# Step 161: discovered 4 changed edges within radius 1
# Step 161: 4 changes detected.
#   → g[8279] before=17.6813, after=17.7668
# Step 162: discovered 4 changed edges within radius 1
# Step 162: 4 changes detected.
#   → g[8280] before=17.1981, after=17.3526
# Step 163: discovered 4 changed edges within radius 1
# Step 163: 4 changes detected.
#   → g[8281] before=16.7830, after=17.0068
# Step 164: discovered 4 changed edges within radius 1
# Step 164: 4 changes detected.
#   → g[8282] before=16.4391, after=16.4949
# Step 165: discovered 4 changed edges within radius 1
# Step 165: 4 changes detected.
#   → g[8382] before=15.9424, after=16.1738
# Step 166: discovered 4 changed edges within radius 1
# Step 166: 4 changes detected.
#   → g[8383] before=15.5810, after=15.7137
# Step 167: discovered 4 changed edges within radius 1
# Step 167: 4 changes detected.
#   → g[8384] before=15.1528, after=15.3053
# Step 168: discovered 4 changed edges within radius 1
# Step 168: 4 changes detected.
#   → g[8385] before=14.7855, after=14.9086
# Step 169: discovered 4 changed edges within radius 1
# Step 169: 4 changes detected.
#   → g[8485] before=14.4193, after=14.4616
# Step 170: discovered 4 changed edges within radius 1
# Step 170: 4 changes detected.
#   → g[8486] before=13.9676, after=14.0750
# Step 171: discovered 4 changed edges within radius 1
# Step 171: 4 changes detected.
#   → g[8586] before=13.6008, after=13.5595
# Step 172: discovered 4 changed edges within radius 1
# Step 172: 4 changes detected.
#   → g[8686] before=13.0958, after=13.1835
# Step 173: discovered 4 changed edges within radius 1
# Step 173: 4 changes detected.
#   → g[8687] before=12.7213, after=12.7316
# Step 174: discovered 4 changed edges within radius 1
# Step 174: 4 changes detected.
#   → g[8787] before=12.2783, after=12.2629
# Step 175: discovered 4 changed edges within radius 1
# Step 175: 4 changes detected.
#   → g[8887] before=11.7960, after=11.8021
# Step 176: discovered 4 changed edges within radius 1
# Step 176: 4 changes detected.
#   → g[8987] before=11.3036, after=11.4337
# Step 177: discovered 4 changed edges within radius 1
# Step 177: 4 changes detected.
#   → g[8988] before=10.8957, after=11.1547
# Step 178: discovered 4 changed edges within radius 1
# Step 178: 4 changes detected.
#   → g[8989] before=10.6170, after=10.8304
# Step 179: discovered 4 changed edges within radius 1
# Step 179: 4 changes detected.
#   → g[9089] before=10.2844, after=10.5463
# Step 180: discovered 4 changed edges within radius 1
# Step 180: 4 changes detected.
#   → g[9090] before=9.9883, after=10.0702
# Step 181: discovered 4 changed edges within radius 1
# Step 181: 4 changes detected.
#   → g[9091] before=9.5123, after=9.7085
# Step 182: discovered 4 changed edges within radius 1
# Step 182: 4 changes detected.
#   → g[9191] before=9.1437, after=9.2974
# Step 183: discovered 4 changed edges within radius 1
# Step 183: 4 changes detected.
#   → g[9192] before=8.7174, after=8.9076
# Step 184: discovered 4 changed edges within radius 1
# Step 184: 4 changes detected.
#   → g[9292] before=8.3081, after=8.5914
# Step 185: discovered 4 changed edges within radius 1
# Step 185: 4 changes detected.
#   → g[9392] before=7.9507, after=8.1608
# Step 186: discovered 4 changed edges within radius 1
# Step 186: 4 changes detected.
#   → g[9492] before=7.4660, after=7.6692
# Step 187: discovered 4 changed edges within radius 1
# Step 187: 4 changes detected.
#   → g[9592] before=6.9193, after=7.0800
# Step 188: discovered 4 changed edges within radius 1
# Step 188: 4 changes detected.
#   → g[9692] before=6.2848, after=6.3535
# Step 189: discovered 4 changed edges within radius 1
# Step 189: 4 changes detected.
#   → g[9693] before=5.5264, after=5.9169
# Step 190: discovered 4 changed edges within radius 1
# Step 190: 4 changes detected.
#   → g[9793] before=5.0636, after=5.3530
# Step 191: discovered 4 changed edges within radius 1
# Step 191: 4 changes detected.
#   → g[9794] before=4.4747, after=4.7376
# Step 192: discovered 4 changed edges within radius 1
# Step 192: 4 changes detected.
#   → g[9795] before=3.8420, after=4.0906
# Step 193: discovered 4 changed edges within radius 1
# Step 193: 4 changes detected.
#   → g[9796] before=3.1883, after=3.5215
# Step 194: discovered 4 changed edges within radius 1
# Step 194: 4 changes detected.
#   → g[9896] before=2.6155, after=2.7721
# Step 195: discovered 4 changed edges within radius 1
# Step 195: 4 changes detected.
#   → g[9897] before=1.8539, after=2.1952
# Step 196: discovered 4 changed edges within radius 1
# Step 196: 4 changes detected.
#   → g[9898] before=1.2684, after=1.5742
# Step 197: discovered 3 changed edges within radius 1
# Step 197: 3 changes detected.
#   → g[9899] before=0.6311, after=0.9621
# Step 198: discovered 2 changed edges within radius 1
# Step 198: 2 changes detected.
#   → g[9999] before=0.0000, after=0.0000
# Saved D* Lite breakdown → /Users/philippstockerl/BachelorThesis/Data/master17/seed_10864_grid100_Stable_ls30.0_var1.0_nug1.0/dstar_results/dstar_solution_breakdown.csv
# Saved D* Lite path nodes → /Users/philippstockerl/BachelorThesis/Data/master17/seed_10864_grid100_Stable_ls30.0_var1.0_nug1.0/dstar_results/dstar_path_nodes.csv
# Saved D* Lite visualization → /Users/philippstockerl/BachelorThesis/Data/master17/seed_10864_grid100_Stable_ls30.0_var1.0_nug1.0/dstar_results/dstar_path_overlay.png
#
# Final D* Lite path has 199 nodes.
# Total Nominal Cost = 117.939, Forecast Cost = 90.399
#
# === D* Lite Export Summary ===
# Path CSV: /Users/philippstockerl/BachelorThesis/Data/master17/seed_10864_grid100_Stable_ls30.0_var1.0_nug1.0/dstar_results/dstar_path_nodes.csv
# Breakdown CSV: /Users/philippstockerl/BachelorThesis/Data/master17/seed_10864_grid100_Stable_ls30.0_var1.0_nug1.0/dstar_results/dstar_solution_breakdown.csv
# Total Nominal Cost: 117.939
# Total Forecast Cost: 90.399
